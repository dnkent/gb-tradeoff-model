# %% [markdown]
# # Arms Races With a Guns-Butter Tradeoff
#
# ### Daniel Kent
# ### kent.249@osu.edu

# %% [markdown]
# + Libraries and the model

# %%
from gb_mod import EconMod

# %matplotlib inline
import matplotlib.pyplot as plt

import random
import numpy as np

import pandas as pd

# %% [markdown]
# ## Example Run

# %% [markdown]
# + Starting parameters

# %%
height = 14
width = 14
density = 1
domestic_min = 0.04 # Min of gdp to extract for governance
domestic_max = 0.32 # Max of gdp to extract for governance
domestic_mean = 0.16 # Mean of gdp to extract for governance
domestic_sd = 0.05 # SD of gdp to extract for governance
expenditures = 0.4 # Vary for final analysis -- percent of extracted rents that must go to public programs
num_adversaries = 4 # Vary for final analysis -- top n neighbors power-wise to consider for balancing
random.seed(54321)

# %% [markdown]
# + Create the model

# %%
model = EconMod(height, width, density, 
                domestic_min, domestic_max, 
                domestic_mean, domestic_sd,
                num_adversaries, expenditures)

# %% [markdown]
# ### Starting Conditions

# %% [markdown]
# #### Economy
#
# + Meant to represent GDP -- drawn from a pareto distribution

# %%
agent_econ = [a.econ for a in model.schedule.agents]

# %%
plt.figure(figsize = (8, 8))
plt.hist(agent_econ)
# plt.savefig('start_hist.png', bbox_inches='tight') ## Save image
plt.show() ## Don't show array output

# %% [markdown]
# #### Arms
#
# + Starting military size. This is just specified as a percent of GDP, randomly drawn from a uniform distribution between 0 and 0.06. From here on out the military size of various agents will be grown by decisions within the model.

# %%
agent_arms = [a.arms for a in model.schedule.agents]

# %%
plt.figure(figsize = (8, 8))
plt.hist(agent_arms)
# plt.savefig('start_hist.png', bbox_inches='tight') ## Save image
plt.show() ## Don't show array output

# %% [markdown]
# + Spatial distribution:

# %%
agent_arms = np.zeros((model.grid.width, model.grid.height))
for a in model.schedule.agents:
    X = a.pos[0]
    Y = a.pos[1]
    arms = a.arms
    agent_arms[X][Y] = arms

# %%
plt.figure(figsize = (13, 9))
plt.imshow(agent_arms, interpolation='nearest', aspect = 'auto', cmap="Blues")
plt.colorbar()
#plt.savefig('arms_start.pdf', bbox_inches='tight') ## Save image
plt.show()

# %% [markdown]
# ### 100 Rounds

# %%
for i in range(100):
    model.step()

# %% [markdown]
# ### Military spending

# %%
agent_arms = np.zeros((model.grid.width, model.grid.height))
for a in model.schedule.agents:
    X = a.pos[0]
    Y = a.pos[1]
    arms = a.arms
    agent_arms[X][Y] = arms

# %%
plt.figure(figsize = (13, 10))
plt.imshow(agent_arms, interpolation='nearest', aspect = 'auto', cmap = 'Blues')
plt.colorbar()
# plt.savefig('grid4.png', bbox_inches='tight') ## save image
plt.show()

# %% [markdown]
# ### Military Spending/Rents
#
# + What percent of a state's total possible government expenditures go to the military. This is the key variable and something that we can't quite get observationally with real data. Out of all the money that a state could extract from its population and industries, how much goes to the military? To the extent that a state is nowhere near its max spending ability for the military, then it is not engaged in an arms race.

# %%
agent_competition = np.zeros((model.grid.width, model.grid.height))
for a in model.schedule.agents:
    X = a.pos[0]
    Y = a.pos[1]
    arms = a.arms
    domestic = a.domestic * a.econ
    agent_competition[X][Y] = arms/domestic

# %%
plt.figure(figsize = (13, 10))
plt.imshow(agent_competition, interpolation='nearest', aspect = 'auto', cmap="Blues")
plt.colorbar()
# plt.savefig('grid1.png', bbox_inches='tight') ## Save image
plt.show()

# %% [markdown]
# + Right now there are some funky patterns, but the model has not yet reached a steady state. Let's let the model run for a while and see where it stabilizes/equilibrates.

# %% [markdown]
# ### 1000 Rounds

# %%
for i in range(1000):
    model.step()

# %% [markdown]
# ### Military spending

# %%
agent_arms = np.zeros((model.grid.width, model.grid.height))
for a in model.schedule.agents:
    X = a.pos[0]
    Y = a.pos[1]
    arms = a.arms
    agent_arms[X][Y] = arms

# %%
plt.figure(figsize = (13, 10))
plt.imshow(agent_arms, interpolation='nearest', aspect = 'auto', cmap = 'Blues')
plt.colorbar()
# plt.savefig('grid4.png', bbox_inches='tight') ## save image
plt.show()

# %% [markdown]
# ### Military spending/GDP

# %%
agent_burden = np.zeros((model.grid.width, model.grid.height))
for a in model.schedule.agents:
    X = a.pos[0]
    Y = a.pos[1]
    burden = a.mil_burden
    agent_burden[X][Y] = burden

# %%
plt.figure(figsize = (13, 10))
plt.imshow(agent_burden, interpolation='nearest', aspect = 'auto', cmap="Blues")
plt.colorbar()
# plt.savefig('grid1.png', bbox_inches='tight') ## Save image
plt.show()

# %% [markdown]
# ### Military Spending/Rents

# %%
agent_competition = np.zeros((model.grid.width, model.grid.height))
for a in model.schedule.agents:
    X = a.pos[0]
    Y = a.pos[1]
    arms = a.arms
    domestic = a.domestic * a.econ
    agent_competition[X][Y] = arms/domestic

# %%
plt.figure(figsize = (13, 10))
plt.imshow(agent_competition, interpolation='nearest', aspect = 'auto', cmap="Blues")
plt.colorbar()
# plt.savefig('grid1.png', bbox_inches='tight') ## Save image
plt.show()

# %% [markdown]
# + Ok, the funky patterns go away. This all looks good.

# %% [markdown]
# ### Stable state arms/available

# %%
# agent_competition = [a.arms / (a.domestic * a.econ) for a in model.schedule.agents]

# %%
plt.figure(figsize = (8, 8))
plt.hist(agent_competition)
# plt.savefig('start_hist.png', bbox_inches='tight') ## Save image
plt.show() ## Don't show array output

# %% [markdown]
# + Ok, so this is great -- the model's stable state of military spending/gdp looks very realistic under these starting conditions. Now, let's do a parameter sweep.

# %% [markdown]
# # Parameter sweeps

# %% [markdown]
# + What is my model-based parameter? -- See Mesa Schelling Jupyter notebook for example code for batchrunner

# %%
from mesa.batchrunner import BatchRunner

fixed_params = {
    "height": 14,
    "width": 14,
    "density": 1,
    "domestic_min": 0.04,
    "domestic_max": 0.32,
    "domestic_mean": 0.16, # Mean of gdp to extract for governance
    "domestic_sd": 0.05 # SD of gdp to extract for governance

}

variable_params = {
    "expenditures": np.arange(0, 1.0, 0.1), # No need to set to 1 or 0.8 -- no arms spending
    "num_adversaries": range(1,9) # range is funny - this is 1,2,3,...,8
}

# %% [markdown]
# + Custom functions:
#     + Number of agents spending less than x% of their domestic rents on arms
#     + Mean % of domestic rents spent on arms
#     + SD of the % of domestic rents spent on arms

# %%
def num_agent_20(model):
    agent_arms = np.zeros((model.grid.width, model.grid.height))
    for a in model.schedule.agents:
        X = a.pos[0]
        Y = a.pos[1]
        arms = a.arms
        agent_arms[X][Y] = arms

    agent_econ = np.zeros((model.grid.width, model.grid.height))
    for a in model.schedule.agents:
        X = a.pos[0]
        Y = a.pos[1]
        econ = a.econ
        agent_econ[X][Y] = econ

    agent_domestic = np.zeros((model.grid.width, model.grid.height))
    for a in model.schedule.agents:
        X = a.pos[0]
        Y = a.pos[1]
        domestic = a.domestic
        agent_domestic[X][Y] = domestic

    mil_dom = agent_arms / (agent_econ * agent_domestic) 
    return ((mil_dom <= .20).sum()/(mil_dom.shape[0] * mil_dom.shape[1]))

def num_agent_40(model):
    agent_arms = np.zeros((model.grid.width, model.grid.height))
    for a in model.schedule.agents:
        X = a.pos[0]
        Y = a.pos[1]
        arms = a.arms
        agent_arms[X][Y] = arms

    agent_econ = np.zeros((model.grid.width, model.grid.height))
    for a in model.schedule.agents:
        X = a.pos[0]
        Y = a.pos[1]
        econ = a.econ
        agent_econ[X][Y] = econ

    agent_domestic = np.zeros((model.grid.width, model.grid.height))
    for a in model.schedule.agents:
        X = a.pos[0]
        Y = a.pos[1]
        domestic = a.domestic
        agent_domestic[X][Y] = domestic

    mil_dom = agent_arms / (agent_econ * agent_domestic) 
    return ((mil_dom <= .40).sum()/(mil_dom.shape[0] * mil_dom.shape[1]))

def num_agent_60(model):
    agent_arms = np.zeros((model.grid.width, model.grid.height))
    for a in model.schedule.agents:
        X = a.pos[0]
        Y = a.pos[1]
        arms = a.arms
        agent_arms[X][Y] = arms

    agent_econ = np.zeros((model.grid.width, model.grid.height))
    for a in model.schedule.agents:
        X = a.pos[0]
        Y = a.pos[1]
        econ = a.econ
        agent_econ[X][Y] = econ

    agent_domestic = np.zeros((model.grid.width, model.grid.height))
    for a in model.schedule.agents:
        X = a.pos[0]
        Y = a.pos[1]
        domestic = a.domestic
        agent_domestic[X][Y] = domestic

    mil_dom = agent_arms / (agent_econ * agent_domestic) 
    return ((mil_dom <= .60).sum()/(mil_dom.shape[0] * mil_dom.shape[1]))

# %%
#def num_agent_20(model):
#    agent_arms = [agent.arms for agent in model.schedule.agents]
#    agent_arms = np.array(agent_arms)
#    agent_dom = [agent.domestic * agent.econ for agent in model.schedule.agents]
#    agent_dom = np.array(agent_dom)
#    mil_dom = np.array(agent_arms/agent_dom)
#    return ((mil_dom <= .20).sum()/len(mil_dom))

#def num_agent_40(model):
#    agent_arms = [agent.arms for agent in model.schedule.agents]
#    agent_arms = np.array(agent_arms)
#    agent_dom = [agent.domestic * agent.econ for agent in model.schedule.agents]
#    agent_dom = np.array(agent_dom)
#    mil_dom = np.array(agent_arms/agent_dom)
#    return ((mil_dom <= .40).sum()/len(mil_dom))

#def num_agent_60(model):
#    agent_arms = [agent.arms for agent in model.schedule.agents]
#    agent_arms = np.array(agent_arms)
#    agent_dom = [agent.domestic * agent.econ for agent in model.schedule.agents]
#    agent_dom = np.array(agent_dom)
#    mil_dom = np.array(agent_arms/agent_dom)
#    return ((mil_dom <= .60).sum()/len(mil_dom))

# %%
model_reporters = {
    "Percent_Sub_20": num_agent_20,
    "Percent_Sub_40": num_agent_40,
    "Percent_Sub_60": num_agent_60
}

# %%
#def mean_mil_dom(model):
#    agent_arms = [agent.arms for agent in model.schedule.agents]
#    agent_arms = np.array(agent_arms)
#    agent_dom = [agent.domestic * agent.econ for agent in model.schedule.agents]
#    agent_dom = np.array(agent_dom)
#    mil_dom = agent_arms/agent_dom
#    return (mil_dom.mean())

# %%
#def sd_mil_dom(model):
#    agent_arms = [agent.arms for agent in model.schedule.agents]
#    agent_arms = np.array(agent_arms)
#    agent_dom = [agent.domestic * agent.econ for agent in model.schedule.agents]
#    agent_dom = np.array(agent_dom)
#    mil_dom = agent_arms/agent_dom
#    return (mil_dom.std())

# %%
# model_reporters = {"Mean_MilDom": mean_mil_dom, "SD_MilDom": sd_mil_dom}

# %% [markdown]
# + **IMPORTANT**: Iteration is the number of iterations per parameter sweep.

# %%
random.seed(54321)

# %%
batch_run = BatchRunner(
    EconMod,
    fixed_parameters = fixed_params,
    variable_parameters = variable_params,
                        iterations = 1, # How many times to try each variable combination?
                        max_steps = 1000,
                        model_reporters = model_reporters
)

# %%
batch_run.run_all()
# Out:
# 80it [20:52, 15.35s/it]

# %%
run_data = batch_run.get_model_vars_dataframe()
run_data
# Out:
#     expenditures  num_adversaries  Run  Percent_Sub_20  Percent_Sub_40  \
# 0            0.0                1    0        0.714286        0.831633
# 1            0.0                2    1        0.561224        0.780612
# 2            0.0                3    2        0.469388        0.709184
# 3            0.0                4    3        0.561224        0.729592
# 4            0.0                5    4        0.535714        0.719388
# 5            0.0                6    5        0.494898        0.637755
# 6            0.0                7    6        0.433673        0.622449
# 7            0.0                8    7        0.362245        0.362245
# 8            0.1                1    8        0.642857        0.795918
# 9            0.1                2    9        0.484694        0.765306
# 10           0.1                3   10        0.469388        0.724490
# 11           0.1                4   11        0.551020        0.714286
# 12           0.1                5   12        0.505102        0.719388
# 13           0.1                6   13        0.443878        0.607143
# 14           0.1                7   14        0.387755        0.530612
# 15           0.1                8   15        0.295918        0.295918
# 16           0.2                1   16        0.673469        0.790816
# 17           0.2                2   17        0.551020        0.806122
# 18           0.2                3   18        0.505102        0.734694
# 19           0.2                4   19        0.464286        0.627551
# 20           0.2                5   20        0.428571        0.576531
# 21           0.2                6   21        0.464286        0.591837
# 22           0.2                7   22        0.321429        0.408163
# 23           0.2                8   23        0.193878        0.193878
# 24           0.3                1   24        0.622449        0.790816
# 25           0.3                2   25        0.520408        0.780612
# 26           0.3                3   26        0.438776        0.693878
# 27           0.3                4   27        0.510204        0.647959
# 28           0.3                5   28        0.448980        0.586735
# 29           0.3                6   29        0.418367        0.464286
# ..           ...              ...  ...             ...             ...
# 50           0.6                3   50        0.505102        0.811224
# 51           0.6                4   51        0.392857        0.693878
# 52           0.6                5   52        0.311224        0.653061
# 53           0.6                6   53        0.250000        0.561224
# 54           0.6                7   54        0.239796        0.418367
# 55           0.6                8   55        0.005102        0.239796
# 56           0.7                1   56        0.464286        1.000000
# 57           0.7                2   57        0.464286        0.989796
# 58           0.7                3   58        0.500000        0.984694
# 59           0.7                4   59        0.377551        0.969388
# 60           0.7                5   60        0.331633        0.989796
# 61           0.7                6   61        0.306122        0.984694
# 62           0.7                7   62        0.219388        0.964286
# 63           0.7                8   63        0.015306        0.969388
# 64           0.8                1   64        0.556122        1.000000
# 65           0.8                2   65        0.612245        1.000000
# 66           0.8                3   66        0.581633        1.000000
# 67           0.8                4   67        0.668367        1.000000
# 68           0.8                5   68        0.642857        1.000000
# 69           0.8                6   69        0.556122        1.000000
# 70           0.8                7   70        0.418367        1.000000
# 71           0.8                8   71        0.362245        1.000000
# 72           0.9                1   72        1.000000        1.000000
# 73           0.9                2   73        1.000000        1.000000
# 74           0.9                3   74        1.000000        1.000000
# 75           0.9                4   75        1.000000        1.000000
# 76           0.9                5   76        1.000000        1.000000
# 77           0.9                6   77        1.000000        1.000000
# 78           0.9                7   78        1.000000        1.000000
# 79           0.9                8   79        1.000000        1.000000
#
#     Percent_Sub_60  height  width  density  domestic_min  domestic_max  \
# 0         0.857143      14     14        1          0.04          0.32
# 1         0.816327      14     14        1          0.04          0.32
# 2         0.734694      14     14        1          0.04          0.32
# 3         0.755102      14     14        1          0.04          0.32
# 4         0.729592      14     14        1          0.04          0.32
# 5         0.647959      14     14        1          0.04          0.32
# 6         0.637755      14     14        1          0.04          0.32
# 7         0.362245      14     14        1          0.04          0.32
# 8         0.846939      14     14        1          0.04          0.32
# 9         0.816327      14     14        1          0.04          0.32
# 10        0.755102      14     14        1          0.04          0.32
# 11        0.729592      14     14        1          0.04          0.32
# 12        0.739796      14     14        1          0.04          0.32
# 13        0.642857      14     14        1          0.04          0.32
# 14        0.540816      14     14        1          0.04          0.32
# 15        0.295918      14     14        1          0.04          0.32
# 16        0.862245      14     14        1          0.04          0.32
# 17        0.831633      14     14        1          0.04          0.32
# 18        0.755102      14     14        1          0.04          0.32
# 19        0.668367      14     14        1          0.04          0.32
# 20        0.607143      14     14        1          0.04          0.32
# 21        0.607143      14     14        1          0.04          0.32
# 22        0.413265      14     14        1          0.04          0.32
# 23        0.193878      14     14        1          0.04          0.32
# 24        0.867347      14     14        1          0.04          0.32
# 25        0.816327      14     14        1          0.04          0.32
# 26        0.714286      14     14        1          0.04          0.32
# 27        0.673469      14     14        1          0.04          0.32
# 28        0.622449      14     14        1          0.04          0.32
# 29        0.489796      14     14        1          0.04          0.32
# ..             ...     ...    ...      ...           ...           ...
# 50        0.994898      14     14        1          0.04          0.32
# 51        0.969388      14     14        1          0.04          0.32
# 52        0.943878      14     14        1          0.04          0.32
# 53        0.918367      14     14        1          0.04          0.32
# 54        0.933673      14     14        1          0.04          0.32
# 55        0.897959      14     14        1          0.04          0.32
# 56        1.000000      14     14        1          0.04          0.32
# 57        1.000000      14     14        1          0.04          0.32
# 58        1.000000      14     14        1          0.04          0.32
# 59        1.000000      14     14        1          0.04          0.32
# 60        1.000000      14     14        1          0.04          0.32
# 61        1.000000      14     14        1          0.04          0.32
# 62        1.000000      14     14        1          0.04          0.32
# 63        1.000000      14     14        1          0.04          0.32
# 64        1.000000      14     14        1          0.04          0.32
# 65        1.000000      14     14        1          0.04          0.32
# 66        1.000000      14     14        1          0.04          0.32
# 67        1.000000      14     14        1          0.04          0.32
# 68        1.000000      14     14        1          0.04          0.32
# 69        1.000000      14     14        1          0.04          0.32
# 70        1.000000      14     14        1          0.04          0.32
# 71        1.000000      14     14        1          0.04          0.32
# 72        1.000000      14     14        1          0.04          0.32
# 73        1.000000      14     14        1          0.04          0.32
# 74        1.000000      14     14        1          0.04          0.32
# 75        1.000000      14     14        1          0.04          0.32
# 76        1.000000      14     14        1          0.04          0.32
# 77        1.000000      14     14        1          0.04          0.32
# 78        1.000000      14     14        1          0.04          0.32
# 79        1.000000      14     14        1          0.04          0.32
#
#     domestic_mean  domestic_sd
# 0            0.16         0.05
# 1            0.16         0.05
# 2            0.16         0.05
# 3            0.16         0.05
# 4            0.16         0.05
# 5            0.16         0.05
# 6            0.16         0.05
# 7            0.16         0.05
# 8            0.16         0.05
# 9            0.16         0.05
# 10           0.16         0.05
# 11           0.16         0.05
# 12           0.16         0.05
# 13           0.16         0.05
# 14           0.16         0.05
# 15           0.16         0.05
# 16           0.16         0.05
# 17           0.16         0.05
# 18           0.16         0.05
# 19           0.16         0.05
# 20           0.16         0.05
# 21           0.16         0.05
# 22           0.16         0.05
# 23           0.16         0.05
# 24           0.16         0.05
# 25           0.16         0.05
# 26           0.16         0.05
# 27           0.16         0.05
# 28           0.16         0.05
# 29           0.16         0.05
# ..            ...          ...
# 50           0.16         0.05
# 51           0.16         0.05
# 52           0.16         0.05
# 53           0.16         0.05
# 54           0.16         0.05
# 55           0.16         0.05
# 56           0.16         0.05
# 57           0.16         0.05
# 58           0.16         0.05
# 59           0.16         0.05
# 60           0.16         0.05
# 61           0.16         0.05
# 62           0.16         0.05
# 63           0.16         0.05
# 64           0.16         0.05
# 65           0.16         0.05
# 66           0.16         0.05
# 67           0.16         0.05
# 68           0.16         0.05
# 69           0.16         0.05
# 70           0.16         0.05
# 71           0.16         0.05
# 72           0.16         0.05
# 73           0.16         0.05
# 74           0.16         0.05
# 75           0.16         0.05
# 76           0.16         0.05
# 77           0.16         0.05
# 78           0.16         0.05
# 79           0.16         0.05
#
# [80 rows x 13 columns]

# %% [markdown]
# + https://stackoverflow.com/questions/46870672/multiple-lines-on-line-plot-time-series-with-matplotlib-or-plot-ly-on-python

# %%
sub_20 = run_data[["expenditures", "num_adversaries", "Percent_Sub_20"]]
sub_40 = run_data[["expenditures", "num_adversaries", "Percent_Sub_40"]]
sub_60 = run_data[["expenditures", "num_adversaries", "Percent_Sub_60"]]

# %%
sub_20.pivot(index="expenditures", columns="num_adversaries", values="Percent_Sub_20").plot()
plt.title("Percent of States Spending Under 20% of Available Rents", fontsize=14, fontweight='bold')
#plt.suptitle("Random Walk Suptitle", fontsize=10)
plt.xlabel("Percent of Rents Going to Non-Military Means")
plt.ylabel("Percent of States Under 20%")
sub_40.pivot(index="expenditures", columns="num_adversaries", values="Percent_Sub_40").plot()
plt.title("Percent of States Spending Under 40% of Available Rents", fontsize=14, fontweight='bold')
#plt.suptitle("Random Walk Suptitle", fontsize=10)
plt.xlabel("Percent of Rents Going to Non-Military Means")
plt.ylabel("Percent of States Under 40%")
sub_60.pivot(index="expenditures", columns="num_adversaries", values="Percent_Sub_60").plot()
plt.title("Percent of States Spending Under 60% of Available Rents", fontsize=14, fontweight='bold')
#plt.suptitle("Random Walk Suptitle", fontsize=10)
plt.xlabel("Percent of Rents Going to Non-Military Means")
plt.ylabel("Percent of States Under 60%")
# Out:
# Text(0, 0.5, 'Percent of States Under 60%')

# %% [markdown]
# #### Saving output: Dill
#
# + https://stackoverflow.com/questions/2960864/how-can-i-save-all-the-variables-in-the-current-python-session
#     + see dill discussion
#
# + https://stackoverflow.com/questions/26106833/save-workspace-in-ipython
#     + Look at dill package discussion

# %%
#import dill                     
#filename = 'globalsave.pkl'
#dill.dump_session(filename)

# %%
# and to load the session again:
# import dill
# filename = 'globalsave.pkl'
# dill.load_session(filename)

# %% [markdown]
# + Lot of interesting stuff about how many countries are limiting arms races. Once we get to at least half of the budget having to go to domestic programs. In fact, given sufficient iterations, regardless of expenditures that must go to the economy or the number of adversaries considered, the model converges to most states not arming up that much. In almost all steady states, states are spending less than 50% of available rents on the military.

# %% [markdown]
# + https://python-graph-gallery.com/122-multiple-lines-chart/ for plot example
#     + Want to have three plots -- percent below 20%, percent below 40%, and percent below 60%. For each plot, we can have 4 lines: balance against most powerful, top 2, top 3, and top 4. X-axis for each is percent of available rents that must be spent on other domestic programs first.

# %% [markdown]
# + No matter how much domestic constraints might vary -- and we can't really observe that -- across domestic constraints we stay in a realistic range when the number of states considered when balancing stays low.

# %% [markdown]
# This is the real plot -- all steady states have more than half of the agents spending less than 40% of available rents on the military.

# %% [markdown]
# ## Interactive visual
# + Go with mil_dom (sincea  fraction) and default visual
# + Then line-charts interactive
